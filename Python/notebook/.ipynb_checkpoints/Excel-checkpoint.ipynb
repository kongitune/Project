# %%
import os
import pandas as pd

# 相対パスの取得
name = os.path.dirname(os.path.abspath(__name__)) 
joined_path = os.path.join(name, '../data/Sample - Superstore.xls')
data_path = os.path.normpath(joined_path)

# Excelファイル要素確認
input_book = pd.ExcelFile(data_path)
print("sheet length：", len(input_book.sheet_names))
print(input_book.sheet_names)
# Out:
# sheet length： 3
# ['Orders', 'Returns', 'People']

# %%
input_sheet_of = input_book.parse(input_sheet_name[0])
print("sheet name:", input_sheet_name[0])

#input_sheet_of.head()
#input_sheet_of.tail()
input_sheet_of.to_csv('./Sample - Superstore.csv', encoding='utf-8')
# Out:
# sheet name: Orders
